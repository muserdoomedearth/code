# %% [markdown]
# ## This notebook is to be used in the capstone project.

# %%
import pandas as pd

# %%
import numpy as np

# %%
print("Hello capstone project course")
# Out:
# Hello capstone project course
